# %%
import os
import re
import numpy as np
import time
import sentencepiece as spm
import Bio
from Bio import SeqIO

ncRNA_path = "/Users/tiananoll-walker/Documents/biotokens/genome_sequences/raw_genomic_files/vertebrates/Mus_musculus_ncrna.fasta"
cds_path = "/Users/tiananoll-walker/Documents/biotokens/genome_sequences/raw_genomic_files/vertebrates/Mus_musculus_cds.fasta"
full_genome_path = "/Users/tiananoll-walker/Documents/biotokens/genome_sequences/raw_genomic_files/vertebrates/Mus_musculus.GRCm39.dna.toplevel.fa"

processing_dir = "/Users/tiananoll-walker/Documents/biotokens/used_code/cds_ncrna_processing_and_tokenization"
subsampled_genomes_dir = os.path.join(processing_dir, "subsampled_genomes")
tokenizers_dir = os.path.join(processing_dir, "tokenizers")
os.makedirs(subsampled_genomes_dir, exist_ok=True)
os.makedirs(tokenizers_dir, exist_ok=True)

def subsample_cds_ncrna(filepath, N=10**7):
    """subsamples the cds or ncrna files based on specified sizes"""
    with open(filepath, 'r') as f:
        text = f.read()
    text = ''.join([i if re.sub('[^ACGT]', '', i) == i else ' ' for i in text.split('\n')])
    cdss = text.split()
    
    subsampled_cdss = []
    subsample_length = 0
    np.random.seed(1872)
    randomized_indices = np.random.choice(range(len(cdss)), len(cdss), replace=False)

    for k in randomized_indices:
        c = cdss[k]
        subsample_length += len(c)
        subsampled_cdss.append(c)
        if subsample_length >= N:
            break
            
    return subsampled_cdss

def subsample_full_genome(filepath, N=10**7):
    """for subsampling the full genome file"""
    with open(filepath, 'r') as f:
        genome = ''.join([line.strip() for line in f if not line.startswith('>')])
    return [genome[i:i+4096] for i in range(0, len(genome), 4096) if i < N]

def save_subsampled_genome(org, file_name, subsample):
    subsample_path = os.path.join(subsampled_genomes_dir, f"{org}_{file_name}_subsampled.txt")
    with open(subsample_path, 'w') as f:
        for seq in subsample:
            f.write(seq + '\n')  # Write each sequence on a new line
    return subsample_path

def train_and_tokenize(input_file, model_prefix, vocab_size=10000):
    spm.SentencePieceTrainer.train(
        input=input_file,
        model_prefix=model_prefix,
        vocab_size=vocab_size,
        model_type='bpe',
        character_coverage=0.9995,
        max_sentence_length=5000,
        hard_vocab_limit=False
    )
    
    sp = spm.SentencePieceProcessor()
    sp.load(f"{model_prefix}.model")
    
    with open(input_file, 'r') as f:
        genome = f.read()
    tokens = sp.encode_as_pieces(genome)
    tokenized_output_file = f"{model_prefix}_tokenized.txt"
    
    with open(tokenized_output_file, "w") as f:
        f.write(" ".join(tokens))
    print(f"tokenized seq saved: {tokenized_output_file}")

def process_file():
    file_paths = {
        "ncRNA": ncRNA_path,
        "CDS": cds_path,
        "Full_Genome": full_genome_path
    }
    sizes = [10**6, 10**7, 10**8]

    #process cds and ncrna else process full genome w random chunks of size 4096
    for file_type, path in file_paths.items():
        for size in sizes:
            print(f"processing {file_type} w size {size}")
            start_time = time.time()
            if file_type in ["ncRNA", "CDS"]:
                subsample = subsample_cds_ncrna(path, N=size)
            else: 
                subsample = subsample_full_genome(path, N=size)
            
            subsample_path = save_subsampled_genome("Mus_musculus", file_type, subsample)

            model_prefix = os.path.join(tokenizers_dir, f"Mus_musculus_{file_type}_tokenizer")
            train_and_tokenize(subsample_path, model_prefix)
            
            end_time = time.time()
            print(f"processing {file_type} w size {size} took {end_time - start_time:.2f} secs")

#process the mousey files
process_file()
# Out:
# processing ncRNA w size 1000000
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /Users/tiananoll-walker/Documents/biotokens/used_code/cds_ncrna_processing_and_tokenization/subsampled_genomes/Mus_musculus_ncRNA_subsampled.txt
#   input_format:
#   model_prefix: /Users/tiananoll-walker/Documents/biotokens/used_code/cds_ncrna_processing_and_tokenization/tokenizers/Mus_musculus_ncRNA_tokenizer
#   model_type: BPE
#   vocab_size: 10000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 5000
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: /Users/tiananoll-walker/Documents/biotokens/used_code/cds_ncrna_processing_and_tokenization/subsampled_genomes/Mus_musculus_ncRNA_subsampled.txt
# trainer_interface.cc(380) LOG(WARNING) Found too long line (6988 > 5000).
# trainer_interface.cc(382) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(383) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(409) LOG(INFO) Loaded all 982 sentences
# trainer_interface.cc(416) LOG(INFO) Skipped 6 too long sentences.
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=960593
# trainer_interface.cc(560) LOG(INFO) Alphabet size=5
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 982 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 982
# trainer_interface.cc(609) LOG(INFO) Done! 978
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=74886 min_freq=109
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7363 size=20 all=489 active=484 piece=ATT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2526 size=40 all=1696 active=1691 piece=TCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1458 size=60 all=3637 active=3632 piece=AAAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=882 size=80 all=6208 active=6203 piece=AGTT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=617 size=100 all=9189 active=9184 piece=TTAC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=598 min_freq=77
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=496 size=120 all=12605 active=4255 piece=TTTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=382 size=140 all=16217 active=7867 piece=AAGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=326 size=160 all=19844 active=11494 piece=TTCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=281 size=180 all=23395 active=15045 piece=TTTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=252 size=200 all=27076 active=18726 piece=ACATC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=247 min_freq=43
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=214 size=220 all=30420 active=4538 piece=TCGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=193 size=240 all=33894 active=8012 piece=ACAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=169 size=260 all=37123 active=11241 piece=TCATG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=280 all=40102 active=14220 piece=TGGGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=141 size=300 all=43084 active=17202 piece=TGTCTC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=140 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=128 size=320 all=45900 active=4832 piece=GGCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=121 size=340 all=48600 active=7532 piece=TGCTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=112 size=360 all=51270 active=10202 piece=AATAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=380 all=53834 active=12766 piece=AGGCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=98 size=400 all=56329 active=15261 piece=ACAGAG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=96 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=420 all=58573 active=4955 piece=AGATCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=440 all=60821 active=7203 piece=TAATAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=82 size=460 all=63043 active=9425 piece=AGATGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76 size=480 all=65236 active=11618 piece=AGTCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=72 size=500 all=67284 active=13666 piece=TCCGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=72 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=520 all=69290 active=5282 piece=ATGGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=540 all=71178 active=7170 piece=AAAGAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=560 all=73063 active=9055 piece=TCGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=580 all=74898 active=10890 piece=AAAGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=600 all=76642 active=12634 piece=TGGTTC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=59 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=620 all=78231 active=5331 piece=AGGAGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=640 all=79902 active=7002 piece=ATGATG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=660 all=81517 active=8617 piece=AACAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=680 all=82929 active=10029 piece=ACCGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=700 all=84503 active=11603 piece=TGCTGTG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=49 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=720 all=86055 active=5702 piece=ATATAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=740 all=87497 active=7144 piece=TGTGGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=760 all=88922 active=8569 piece=ACTCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=780 all=90346 active=9993 piece=TCCATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=800 all=91628 active=11275 piece=TGTCTGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=41 min_freq=9
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=820 all=92879 active=5767 piece=AGTAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=840 all=94086 active=6974 piece=TGCTAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=860 all=95343 active=8231 piece=AGCCTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=880 all=96507 active=9395 piece=AGGAGAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=900 all=97649 active=10537 piece=TTCCTTCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=35 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=920 all=98704 active=5919 piece=TGATGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=940 all=99808 active=7023 piece=AAGAGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq
C
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3420 all=156828 active=8056 piece=AGGGTGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3440 all=157064 active=8292 piece=ATTTACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3460 all=157280 active=8508 piece=TAATTGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3480 all=157527 active=8755 piece=TATTTAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3500 all=157772 active=9000 piece=TGAGACG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3520 all=158018 active=8122 piece=TGTTCCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3540 all=158251 active=8355 piece=TTGACCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3560 all=158498 active=8602 piece=AAATAGAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3580 all=158741 active=8845 piece=ACACAAAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3600 all=158963 active=9067 piece=AGACTGCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3620 all=159196 active=8170 piece=ATAAAACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3640 all=159424 active=8398 piece=ATTGTATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3660 all=159636 active=8610 piece=TCTCCCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3680 all=159866 active=8840 piece=TGCTCTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3700 all=160086 active=9060 piece=TTCCATCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3720 all=160326 active=8231 piece=AAAATAAAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3740 all=160498 active=8403 piece=TCCCCTTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=3760 all=160645 active=8550 piece=AGGAACCCAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3780 all=160704 active=8609 piece=▁AGTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3800 all=160891 active=8796 piece=TCGTCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3820 all=161102 active=8245 piece=AAGGCCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3840 all=161307 active=8450 piece=ACTGTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3860 all=161511 active=8654 piece=AGTGTAT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3880 all=161714 active=8857 piece=ATGATTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3900 all=161914 active=9057 piece=TAAATGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3920 all=162121 active=8292 piece=TATGATG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3940 all=162331 active=8502 piece=TCCTCTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3960 all=162544 active=8715 piece=TGGGAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=3980 all=162750 active=8921 piece=TTGAAAT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4000 all=162958 active=9129 piece=TTTGTGG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4020 all=163164 active=8343 piece=AACTCTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4040 all=163359 active=8538 piece=AATTTCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4060 all=163548 active=8727 piece=ACCCCTGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4080 all=163752 active=8931 piece=AGAGGGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4100 all=163949 active=9128 piece=AGGCAGAC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4120 all=164151 active=8389 piece=ATACAAAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4140 all=164333 active=8571 piece=ATGCAGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4160 all=164515 active=8753 piece=TAGACAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4180 all=164700 active=8938 piece=TCAGCCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4200 all=164898 active=9136 piece=TGAACCCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4220 all=165102 active=8439 piece=TGGAACCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4240 all=165293 active=8630 piece=TGGGTGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4260 all=165484 active=8821 piece=TTCCCAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4280 all=165677 active=9014 piece=TTGTTTTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4300 all=165867 active=9204 piece=AAGCTGATC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4320 all=166013 active=8437 piece=AGAGGATTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4340 all=166175 active=8599 piece=GCCCTCTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4360 all=166297 active=8721 piece=TGACCCCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4380 all=166443 active=8867 piece=TTCGAGGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4400 all=166530 active=8954 piece=TATTTCCTCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4420 all=166573 active=8365 piece=TGGATGGATTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=4440 all=166565 active=8357 piece=ATGCCACTGCTTAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4460 all=166637 active=8429 piece=ACTGCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4480 all=166796 active=8588 piece=TGCGCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4500 all=166955 active=8747 piece=AAGATAA
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4520 all=167130 active=8514 piece=AATTTAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4540 all=167305 active=8689 piece=ACGAACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4560 all=167476 active=8860 piece=AGGAGTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4580 all=167648 active=9032 piece=ATAGATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4600 all=167811 active=9195 piece=ATTGATT
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4620 all=167962 active=8533 piece=TAACTAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4640 all=168126 active=8697 piece=TAGTGTT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4660 all=168289 active=8860 piece=TCCAGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4680 all=168455 active=9026 piece=TGCCCGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4700 all=168632 active=9203 piece=TTAGCTC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4720 all=168810 active=8601 piece=TTGTAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4740 all=168975 active=8766 piece=AAACTAAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4760 all=169136 active=8927 piece=AACATTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4780 all=169297 active=9088 piece=AAGGCATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4800 all=169458 active=9249 piece=ACAGAGCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4820 all=169612 active=8618 piece=ACTGTGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4840 all=169774 active=8780 piece=AGAGTGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4860 all=169927 active=8933 piece=AGGAAAAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4880 all=170091 active=9097 piece=AGGTTTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4900 all=170253 active=9259 piece=ATAGCAGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4920 all=170408 active=8659 piece=ATGCCAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4940 all=170581 active=8832 piece=ATTGCAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4960 all=170728 active=8979 piece=TAAGAGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=4980 all=170886 active=9137 piece=TATATCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5000 all=171048 active=9299 piece=TCCCAGGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5020 all=171216 active=8711 piece=TGAATTTT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5040 all=171369 active=8864 piece=TGCTCAAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5060 all=171528 active=9023 piece=TGGGAAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5080 all=171685 active=9180 piece=TGTGTGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5100 all=171848 active=9343 piece=TTCTGGGG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5120 all=172009 active=8744 piece=TTTGCTGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5140 all=172162 active=8897 piece=AAGAAATTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5160 all=172269 active=9004 piece=ACGAAGAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5180 all=172385 active=9120 piece=AGGAAAGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5200 all=172508 active=9243 piece=ATGAATATG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5220 all=172641 active=8749 piece=TCACAGTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5240 all=172750 active=8858 piece=TGAAACAAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5260 all=172873 active=8981 piece=TGGAAAGAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5280 all=172997 active=9105 piece=TTCTCAACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5300 all=173097 active=9205 piece=AAGTGGAAAC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5320 all=173150 active=8699 piece=TCTGCTTTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5340 all=173209 active=8758 piece=AAACTTCTTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5360 all=173210 active=8759 piece=TTCATGCTCAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5380 all=173213 active=8762 piece=AAAAAAAAAAATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5400 all=173198 active=8747 piece=ACCTGTCACCTGTC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5420 all=173179 active=8641 piece=TGTGGCCGCCGAGCAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5440 all=173262 active=8724 piece=ATACGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5460 all=173396 active=8858 piece=TCGTAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5480 all=173517 active=8979 piece=AACCCGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5500 all=173648 active=9110 piece=AATTAGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5520 all=173769 active=8796 piece=ACGTTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5540 all=173903 active=8930 piece=AGCTTCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5560 all=174039 active=9066 piece=ATCAATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5580 all=174164 active=9191 piece=ATTATGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5600 all=174286 active=9313 piece=GGCAGAG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5620 all=174418 active=8839 piece=TAAGATG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5640 all=174550 active=8971 piece=TAGACTT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5660 all=174686 active=9107 piece=TCATAAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5680 all=174816 active=9237 piece=TGCAAAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5700 all=174948 active=9369 piece=TGTACGG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5720 all=175084 active=8878 piece=TTCTACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5740 all=175219 active=9013 piece=AAACAATG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5760 all=175335 active=9129 piece=AACACTTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5780 all=175462 active=9256 piece=AAGCCTAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5800 all=175578 active=9372 piece=AATTTGGG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5820 all=175711 active=8905 piece=ACAGTTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5840 all=175841 active=9035 piece=ACTATGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5860 all=175959 active=9153 piece=AGAATATT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5880 all=176080 active=9274 piece=AGATGATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5900 all=176203 active=9397 piece=AGCTTGCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5920 all=176335 active=8935 piece=AGGCTAAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5940 all=176462 active=9062 piece=AGGTTCGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5960 all=176593 active=9193 piece=AGTGTGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=5980 all=176722 active=9322 piece=ATATATGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6000 all=176850 active=9450 piece=ATGCAGAG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6020 all=176975 active=8960 piece=ATTAATAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6040 all=177096 active=9081 piece=CCCCAACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6060 all=177207 active=9192 piece=TAAATTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6080 all=177335 active=9320 piece=TACTGGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6100 all=177464 active=9449 piece=TATCCTCG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6120 all=177601 active=9003 piece=TCAAATAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6140 all=177724 active=9126 piece=TCCACCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6160 all=177853 active=9255 piece=TCGGAAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6180 all=177980 active=9382 piece=TCTTCTGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6200 all=178108 active=9510 piece=TGAGCCGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6220 all=178242 active=9032 piece=TGATTTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6240 all=178366 active=9156 piece=TGCTTATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6260 all=178486 active=9276 piece=TGGGGATT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6280 all=178610 active=9400 piece=TGTGAAAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6300 all=178730 active=9520 piece=TTACCTAG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6320 all=178859 active=9062 piece=TTGAGGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6340 all=178990 active=9193 piece=TTGTTATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6360 all=179116 active=9319 piece=TTTGAAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6380 all=179232 active=9435 piece=AAACTCACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6400 all=179332 active=9535 piece=AAGCCTCTC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6420 all=179431 active=9058 piece=ACACCTGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6440 all=179509 active=9136 piece=AGACACAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6460 all=179605 active=9232 piece=AGCAGGAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6480 all=179722 active=9349 piece=AGGCCCTAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6500 all=179820 active=9447 piece=ATAAATATG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6520 all=179921 active=9085 piece=ATGAAGAAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6540 all=180026 active=9190 piece=ATTACAGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6560 all=180119 active=9283 piece=TAAAGCATT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6580 all=180220 active=9384 piece=TCAGAGGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6600 all=180309 active=9473 piece=TCTCTGGGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6620 all=180415 active=9114 piece=TGACAACGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6640 all=180509 active=9208 piece=TGCTATATT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6660 all=180592 active=9291 piece=TGGGCTTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6680 all=180701 active=9400 piece=TGTTGTGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6700 all=180803 active=9502 piece=TTCTCTGCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6720 all=180897 active=9130 piece=TTTGCCTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6740 all=180961 active=9194 piece=AAGTCATTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6760 all=180994 active=9227 piece=AGACTCCTGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6780 all=181041 active=9274 piece=AGTCCTCCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6800 all=181092 active=9325 piece=CCCACCGGCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6820 all=181131 active=9094 piece=TCTGAGGTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6840 all=181165 active=9128 piece=TGGATCTGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6860 all=181204 active=9167 piece=TTCTGCTTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6880 all=181229 active=9192 piece=ACGAGCTGCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6900 all=181235 active=9198 piece=TAGGGTTGTTG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6920 all=181257 active=9084 piece=TTGAAGAACAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6940 all=181248 active=9075 piece=ACAGAGACATCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6960 all=181238 active=9065 piece=TCTCCTTGCGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6980 all=181228 active=9055 piece=AGCCCTGTCTCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7000 all=181212 active=9039 piece=TTCTGGTGGATAC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7020 all=181192 active=9041 piece=ATCCAACTTGTTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7040 all=181172 active=9021 piece=AAGATGTTTGTGGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7060 all=181152 active=9001 piece=TGGAGCTTCCTGCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7080 all=181132 active=8981 piece=TTCATTTCACTATACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7100 all=181169 active=9018 piece=▁ATCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7120 all=181247 active=9134 piece=GCCATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7140 all=181332 active=9219 piece=TTTGCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=
CC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=7900 all=919232 active=49112 piece=TGGGGTTG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=7920 all=919896 active=46596 piece=TTGCAGTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=7940 all=920493 active=47193 piece=AAGAATATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=7960 all=921081 active=47781 piece=ACCCTCCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=7980 all=921704 active=48404 piece=AGCAGCCAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=8000 all=922343 active=49043 piece=AGTCTGTGG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=8020 all=922900 active=46645 piece=TCTCTGTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=8040 all=923504 active=47249 piece=TTCCAGCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=8060 all=923714 active=47459 piece=ATGGAAACTTATGTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8080 all=924186 active=47931 piece=ACGTCGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8100 all=924855 active=48600 piece=GCCTTGG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8120 all=925528 active=46884 piece=TGAAACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8140 all=926180 active=47536 piece=AAAGTATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8160 all=926812 active=48168 piece=AATGCCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8180 all=927436 active=48792 piece=ACGACTCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8200 all=928077 active=49433 piece=AGGCACAC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8220 all=928722 active=47015 piece=ATGGATCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8240 all=929339 active=47632 piece=TATAGAGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8260 all=929982 active=48275 piece=TGACTATT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8280 all=930606 active=48899 piece=TGGTCCAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8300 all=931257 active=49550 piece=TTGTGGGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8320 all=931830 active=47102 piece=AAGCCTGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8340 all=932372 active=47644 piece=AGAAAGCTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8360 all=932924 active=48196 piece=AGCCTGCTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8380 all=933511 active=48783 piece=ATATGAATG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8400 all=934036 active=49308 piece=TCCTCGGCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8420 all=934628 active=47263 piece=TGGATGGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8440 all=935206 active=47841 piece=TTCGAGGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=8460 all=935651 active=48286 piece=TCCACACTCCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8480 all=936012 active=48647 piece=AATAGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8500 all=936637 active=49272 piece=GGCAGTC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8520 all=937259 active=47428 piece=TGTCTAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8540 all=937843 active=48012 piece=AACAAAAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8560 all=938469 active=48638 piece=AATTTATG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8580 all=939049 active=49218 piece=ACGATGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8600 all=939647 active=49816 piece=AGCGCCCG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8620 all=940222 active=47533 piece=ATACAGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8640 all=940820 active=48131 piece=ATGGCCCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8660 all=941396 active=48707 piece=TAATGGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8680 all=941988 active=49299 piece=TCCCCGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8700 all=942588 active=49899 piece=TGCGGCGG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8720 all=943188 active=47699 piece=TTTCAAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8740 all=943730 active=48241 piece=AAGCTGGTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8760 all=944249 active=48760 piece=ACTGAGTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8780 all=944781 active=49292 piece=AGCCAGGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8800 all=945286 active=49797 piece=AGGGATTCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8820 all=945784 active=47735 piece=ATGGTGCTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8840 all=946302 active=48253 piece=TGCCAGTGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8860 all=946838 active=48789 piece=TGTCTCTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=8880 all=947325 active=49276 piece=ATGGAGCTGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=8900 all=947674 active=49625 piece=AATTTAG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=8920 all=948286 active=47968 piece=TACTGCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=8940 all=948865 active=48547 piece=AAAAACTT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=8960 all=949431 active=49113 piece=AAGAACGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=8980 all=949996 active=49678 piece=AATGGGGG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9000 all=950570 active=50252 piece=AGAACTGC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9020 all=951162 active=48092 piece=AGGGCCCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9040 all=951747 active=48677 piece=ATCCGCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9060 all=952308 active=49238 piece=ATTGTTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9080 all=952874 active=49804 piece=TCAACGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9100 all=953451 active=50381 piece=TGAGAGCG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9120 all=954020 active=48216 piece=TGTGGCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9140 all=954583 active=48779 piece=TTTGGAAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9160 all=955070 active=49266 piece=AAGACAATG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9180 all=955550 active=49746 piece=ACCCCAGTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9200 all=956071 active=50267 piece=AGCAGGACC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9220 all=956564 active=48272 piece=AGGACCGGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9240 all=957044 active=48752 piece=ATCCACATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9260 all=957528 active=49236 piece=TAAAGAAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9280 all=957989 active=49697 piece=TGGAGCCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9300 all=958482 active=50190 piece=TTACAGAAG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=9320 all=958935 active=48352 piece=TACAACACAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9340 all=959257 active=48674 piece=AACGACG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9360 all=959819 active=49236 piece=AGTAGCG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9380 all=960360 active=49777 piece=TCAATAA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9400 all=960890 active=50307 piece=TTCGACG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9420 all=961441 active=48564 piece=AACATGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9440 all=961982 active=49105 piece=AATCCTGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9460 all=962516 active=49639 piece=ACTCACTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9480 all=963076 active=50199 piece=AGCTATTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9500 all=963616 active=50739 piece=AGTTACTG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9520 all=964176 active=48714 piece=ATGCCCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9540 all=964731 active=49269 piece=GGGTGGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9560 all=965254 active=49792 piece=TCCCAGTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9580 all=965787 active=50325 piece=TGCTTTTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9600 all=966321 active=50859 piece=TTACCCCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9620 all=966842 active=48809 piece=TTGTGCTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9640 all=967341 active=49308 piece=AAAGAGGAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9660 all=967804 active=49771 piece=AAGCTGCTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9680 all=968236 active=50203 piece=ACCTGATGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9700 all=968724 active=50691 piece=AGCAGACCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9720 all=969213 active=48905 piece=AGGCTCTTC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9740 all=969696 active=49388 piece=ATCCACAAC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9760 all=970163 active=49855 piece=ATTCTGAAG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9780 all=970613 active=50305 piece=TGCAGCGCC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9800 all=971118 active=50810 piece=TGGCTACCC
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9820 all=971584 active=48998 piece=TTGGAAATC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=9840 all=971962 active=49376 piece=AGGAAGAAGC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=9860 all=972148 active=49562 piece=GGGATT
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=9880 all=972684 active=50098 piece=AGTTACG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=9900 all=973200 active=50614 piece=TAACTTG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=16 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=9920 all=973720 active=49158 piece=TTCGACC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=9940 all=974236 active=49674 piece=AACCAGTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=9960 all=974729 active=50167 piece=AAGTGCTG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=9980 all=975245 active=50683 piece=ACGGAGGC
# trainer_interface.cc(687) LOG(INFO) Saving model: /Users/tiananoll-walker/Documents/biotokens/used_code/cds_ncrna_processing_and_tokenization/tokenizers/Mus_musculus_CDS_tokenizer.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: /Users/tiananoll-walker/Documents/biotokens/used_code/cds_ncrna_processing_and_tokenization/tokenizers/Mus_musculus_CDS_tokenizer.vocab
# tokenized seq saved: /Users/tiananoll-walker/Documents/biotokens/used_code/cds_ncrna_processing_and_tokenization/tokenizers/Mus_musculus_CDS_tokenizer_tokenized.txt
# processing CDS w size 10000000 took 144.07 secs
# processing CDS w size 100000000
